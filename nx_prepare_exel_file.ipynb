# %%
import mitosheet
import pandas as pd
may_transactions = pd.read_csv('data4_may_transactions.csv')
june_transactions = pd.read_csv('data4_june_transactions.csv')

mitosheet.sheet(may_transactions,june_transactions , analysis_to_replay="id-zewxgedwrz")
# Out:
# <div id=9512dacf-5915-4607-8fb2-f214239dc243 class="mito-container-container">
#         <script>
# ...

# %%
from mitosheet.public.v3 import *; register_analysis("id-zewxgedwrz");
import pandas as pd

# Exports 2 to file equity_transactions.xlsx
with pd.ExcelWriter("equity_transactions.xlsx") as writer:
    may_transactions.to_excel(writer, sheet_name="may_transactions", index=False)
    june_transactions.to_excel(writer, sheet_name="june_transactions", index=False)
